# %% [markdown]
# # Project D4: Predicting LoL winner

# %% [markdown]
# Team members - Veronika Kukk, Robin Piir, Otto Kase
# <br>Github - https://github.com/VeronikaKukk/DS_project

# %% [markdown]
# # Gathering data

# %% [markdown]
# Data was gathered from Riot API by using development API key.
# <br> Code for that is written in request_info.py.
# <br> This gathering method has already removed any games that were less than 10 minutes and has only taken ranked games from players with rank Diamond I in ranked solo.

# %%
# everything that needs to be imported (libraries)
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import TwoSlopeNorm

# Model
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Combining data

# %% [markdown]
# To analyze servers we first need to combine files from those servers into one. This means that all of EUNE data will be in one dataframe and all of EUW data will be in one dataframe.

# %%
# import all eune files to dataframes
df_eune1 = pd.read_csv("eune_data1.csv", index_col=0)
df_eune2 = pd.read_csv("eune_data2.csv", index_col=0)
df_eune3 = pd.read_csv("eune_data3.csv", index_col=0)
df_eune4 = pd.read_csv("eune_data4.csv", index_col=0)

# %%
# import all euw files to dataframes
df_euw1 = pd.read_csv("euw_data1.csv", index_col=0)
df_euw2 = pd.read_csv("euw_data2.csv", index_col=0)
df_euw3 = pd.read_csv("euw_data3.csv", index_col=0)
df_euw4 = pd.read_csv("euw_data4.csv", index_col=0)

# %%
df_eune1
# Out:
#               matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0     EUN1_3250387583              118                   4               1
# 1     EUN1_3250345989               15                   2               0
# 2     EUN1_3250132600               13                   0               0
# 3     EUN1_3250109344               10                   1               1
# 4     EUN1_3250074417               12                   0               0
# ...               ...              ...                 ...             ...
# 4063  EUN1_3241781223              112                   1               1
# 4064  EUN1_3241746052               17                   5               1
# 4065  EUN1_3241710887               16                   1               0
# 4066  EUN1_3241682864               34                   1               0
# 4067  EUN1_3241627562               15                  16               0
#
#       blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 0             4           3            5            0            0
# 1             7           3            5            0            0
# 2             3           2            3            0            0
# 3             3           3            0            0            0
# 4             0           4            0            0            0
# ...         ...         ...          ...          ...          ...
# 4063         12           4           10            1            0
# 4064         13           6           20            0            0
# 4065          3           9            3            0            0
# 4066          4           7            2            0            0
# 4067          6           9            6            0            0
#
#       blueEliteMonsters  ...  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                     0  ...         14267          7.0               16956
# 1                     0  ...         13815          6.4               15507
# 2                     0  ...         14202          7.0               17682
# 3                     0  ...         14684          6.6               16566
# 4                     0  ...         14784          6.6               16370
# ...                 ...  ...           ...          ...                 ...
# 4063                  1  ...         14534          6.4               15108
# 4064                  0  ...         15496          6.4               16230
# 4065                  0  ...         17167          6.6               16519
# 4066                  0  ...         14538          6.4               14915
# 4067                  0  ...         16743          6.4               15112
#
#       redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                       193                           72            8
# 1                       183                           48         1397
# 2                       205                           48         -544
# 3                       194                           60         -541
# 4                       203                           50        -2446
# ...                     ...                          ...          ...
# 4063                    175                           52         3242
# 4064                    195                           64         3805
# 4065                    171                           56        -3654
# 4066                    171                           36          568
# 4067                    182                           56        -1428
#
#       redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 0                 -2314    21.436862    1584.661722         0
# 1                   893    20.325918    1534.440213         1
# 2                 -1343    22.768502    1577.357373         0
# 3                   111    21.549689    1631.111531         1
# 4                 -2208    22.544534    1641.863978         0
# ...                 ...          ...            ...       ...
# 4063               2265    19.439261    1614.458367         1
# 4064               1745    21.659246    1721.188111         1
# 4065              -1748    18.995111    1906.953580         1
# 4066               1714    18.995181    1614.923621         0
# 4067               -119    20.216195    1859.778844         0
#
# [4068 rows x 40 columns]

# %%
# combining all of the dataframes of both servers into one
eune_dfs = [df_eune1, df_eune2, df_eune3, df_eune4]
euw_dfs = [df_euw1, df_euw2, df_euw3, df_euw4]

df_eune = pd.concat(eune_dfs, ignore_index=True)
df_euw = pd.concat(euw_dfs, ignore_index=True)

# %%
df_eune
# Out:
#                matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0      EUN1_3250387583              118                   4               1
# 1      EUN1_3250345989               15                   2               0
# 2      EUN1_3250132600               13                   0               0
# 3      EUN1_3250109344               10                   1               1
# 4      EUN1_3250074417               12                   0               0
# ...                ...              ...                 ...             ...
# 16246  EUN1_3245368080               75                   4               1
# 16247  EUN1_3245264423                9                   3               0
# 16248  EUN1_3245007949               14                   0               0
# 16249  EUN1_3244978461               11                   1               0
# 16250  EUN1_3244934110               13                   1               1
#
#        blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 0              4           3            5            0            0
# 1              7           3            5            0            0
# 2              3           2            3            0            0
# 3              3           3            0            0            0
# 4              0           4            0            0            0
# ...          ...         ...          ...          ...          ...
# 16246          6           6            8            0            0
# 16247          1           6            1            0            0
# 16248          4           7            5            0            0
# 16249          0           9            0            0            0
# 16250          6           2            8            1            0
#
#        blueEliteMonsters  ...  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                      0  ...         14267          7.0               16956
# 1                      0  ...         13815          6.4               15507
# 2                      0  ...         14202          7.0               17682
# 3                      0  ...         14684          6.6               16566
# 4                      0  ...         14784          6.6               16370
# ...                  ...  ...           ...          ...                 ...
# 16246                  0  ...         15542          6.6               16303
# 16247                  0  ...         14910          6.4               16199
# 16248                  0  ...         14705          6.6               16327
# 16249                  0  ...         15390          6.2               15396
# 16250                  1  ...         13260          6.0               14505
#
#        redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                        193                           72            8
# 1                        183                           48         1397
# 2                        205                           48         -544
# 3                        194                           60         -541
# 4                        203                           50        -2446
# ...                      ...                          ...          ...
# 16246                    194                           56         -509
# 16247                    185                           40        -1725
# 16248                    164                           56         -501
# 16249                    169                           44        -2950
# 16250                    208                           26         2873
#
#        redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 0                  -2314    21.436862    1584.661722         0
# 1                    893    20.325918    1534.440213         1
# 2                  -1343    22.768502    1577.357373         0
# 3                    111    21.549689    1631.111531         1
# 4                  -2208    22.544534    1641.863978         0
# ...                  ...          ...            ...       ...
# 16246              -1744    21.549649    1726.415723         1
# 16247              -1144    20.548097    1656.065576         0
# 16248               -496    18.216353    1633.362583         1
# 16249               -967    18.771764    1709.452342         0
# 16250               2754    23.103111    1472.823300         1
#
# [16251 rows x 40 columns]

# %%
df_euw
# Out:
#                matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0      EUW1_6141576712               13                   0               0
# 1      EUW1_6141532322               11                   1               0
# 2      EUW1_6141500534               11                   2               1
# 3      EUW1_6141433343               16                   4               0
# 4      EUW1_6141410859               12                   6               1
# ...                ...              ...                 ...             ...
# 15978  EUW1_6066115292               13                   4               1
# 15979  EUW1_6064645200               16                   0               1
# 15980  EUW1_6064572344               11                   1               0
# 15981  EUW1_6064260946               12                   1               0
# 15982  EUW1_6061815345               15                   1               0
#
#        blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 0              2           8            1            0            0
# 1             10          13           12            0            0
# 2              8           8            9            1            0
# 3              8           7            7            0            0
# 4              4           8            2            0            0
# ...          ...         ...          ...          ...          ...
# 15978         11           6           10            0            0
# 15979         20           6           14            0            0
# 15980          7           9           10            0            0
# 15981          5           7            6            0            0
# 15982          7           9            5            0            0
#
#        blueEliteMonsters  ...  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                      0  ...         17711          6.8               17142
# 1                      0  ...         18593          6.4               16496
# 2                      1  ...         15676          6.2               15514
# 3                      0  ...         15287          6.2               15702
# 4                      0  ...         17163          6.8               17342
# ...                  ...  ...           ...          ...                 ...
# 15978                  0  ...         14745          6.2               14569
# 15979                  0  ...         14590          5.8               14197
# 15980                  0  ...         15766          6.6               16694
# 15981                  0  ...         15865          6.6               16212
# 15982                  0  ...         16157          6.0               14779
#
#        redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                        231                           50        -4725
# 1                        168                           52         -788
# 2                        162                           40          648
# 3                        198                           36         1181
# 4                        218                           52        -2724
# ...                      ...                          ...          ...
# 15978                    137                           40         3023
# 15979                    141                           43         6159
# 15980                    199                           48         1619
# 15981                    195                           53        -1194
# 15982                    165                           37        -1925
#
#        redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 0                  -2951    25.657544    1967.189444         0
# 1                    127    18.661725    2065.341956         0
# 2                  -1210    17.994502    1741.245730         1
# 3                   1308    21.994461    1698.127879         0
# 4                  -1242    24.216930    1906.583376         1
# ...                  ...          ...            ...       ...
# 15978               1524    15.217037    1637.775277         0
# 15979               4105    15.662519    1620.681931         1
# 15980               -109    22.106199    1751.388580         1
# 15981              -2290    21.659206    1762.170808         0
# 15982              -1324    18.328921    1794.790143         0
#
# [15983 rows x 40 columns]

# %% [markdown]
# # Cleaning data

# %%
# Find whether any games have no values
eune_nan = df_eune.isna().any(axis=1).sum()
euw_nan = df_euw.isna().any(axis=1).sum()
print("Number of missing values in EUNE: "+str(eune_nan))
print("Number of missing values in EUW: "+str(euw_nan))
# Out:
# Number of missing values in EUNE: 0
# Number of missing values in EUW: 0

# %% [markdown]
# This means that there are no rows with missing values. No need to remove any rows because of this.

# %% [markdown]
# ### Inspecting the mean, min and max

# %%
# Since we want to see all columns, we set the max_columns to None
pd.set_option('display.max_columns', None)
df_eune.describe()
# Out:
#        blueWardsPlaced  blueWardsDestroyed  blueFirstBlood     blueKills  \
# count     16251.000000        16251.000000    16251.000000  16251.000000
# mean         18.836133            2.004800        0.507353      5.689373
# std          20.162360            1.893432        0.499961      2.754621
# min           2.000000            0.000000        0.000000      0.000000
# 25%          11.000000            1.000000        0.000000      4.000000
# 50%          13.000000            2.000000        1.000000      5.000000
# 75%          16.000000            3.000000        1.000000      7.000000
# max         306.000000           25.000000        1.000000     21.000000
#
#          blueDeaths   blueAssists   blueDragons   blueHeralds  \
# count  16251.000000  16251.000000  16251.000000  16251.000000
# mean       5.608455      5.698542      0.231309      0.063319
# std        2.726233      3.655421      0.421682      0.243544
# min        0.000000      0.000000      0.000000      0.000000
# 25%        4.000000
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      4.000000      4.000000      3.000000      0.000000
# 50%         1.000000      5.000000      5.000000      5.000000      0.000000
# 75%         1.000000      7.000000      7.000000      8.000000      0.000000
# max         1.000000     22.000000     20.000000     34.000000      1.000000
#
#          redHeralds  redEliteMonsters  redTowersDestroyed  redTotalGold  \
# count  15983.000000      15983.000000        15983.000000   15983.00000
# mean       0.080773          0.327973            0.005381   15158.59801
# std        0.272495          0.506667            0.085025    1425.33718
# min        0.000000          0.000000            0.000000   10722.00000
# 25%        0.000000          0.000000            0.000000   14146.00000
# 50%        0.000000          0.000000            0.000000   15060.00000
# 75%        0.000000          1.000000            0.000000   16043.50000
# max        1.000000          2.000000            5.000000   24040.00000
#
#         redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# count  15983.000000        15983.000000           15983.000000
# mean       6.426666        15835.024526             188.122881
# std        0.276972          984.703982              19.612040
# min        4.400000         9618.000000              96.000000
# 25%        6.200000        15222.000000             175.000000
# 50%        6.400000        15857.000000             189.000000
# 75%        6.600000        16494.500000             201.000000
# max        7.400000        19906.000000             266.000000
#
#        redTotalJungleMinionsKilled   redGoldDiff  redExperienceDiff  \
# count                 15983.000000  15983.000000       15983.000000
# mean                     50.059939    -18.022211         -35.439029
# std                       9.084871   2171.882669        1524.580023
# min                       0.000000 -12288.000000      -10667.000000
# 25%                      44.000000  -1424.500000       -1007.500000
# 50%                      49.000000    -15.000000         -28.000000
# 75%                      56.000000   1394.000000         944.000000
# max                      84.000000  10075.000000        7154.000000
#
#         redCSPerMin  redGoldPerMin      bluewins
# count  15983.000000   15983.000000  15983.000000
# mean      20.896003    1683.759241      0.488081
# std        2.177910     158.228732      0.499874
# min       10.662500    1190.870217      0.000000
# 25%       19.439459    1571.335744      0.000000
# 50%       20.991720    1672.886816      0.000000
# 75%       22.328289    1782.072087      1.000000
# max       28.769839    2580.772955      1.000000

# %% [markdown]
# We found an anomaly with WardsPlaced (for both teams and both servers). It is unlikely that a team places more than ~X wards before 10 minutes, so we investigated why it is like that.
# Our first thought was that it is possible that Riot counts some player abilities as wards, because those abilities give vison to the player.

# %%
# Finding the matchId
df_euw.loc[df_euw["blueWardsPlaced"]==286]
# Out:
#               matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 8525  EUW1_6131485050              286                   0               0
#
#       blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 8525          3           6            1            0            0
#
#       blueEliteMonsters  blueTowersDestroyed  blueTotalGold  blueAvgLevel  \
# 8525                  0                    0          14055           6.6
#
#       blueTotalExperience  blueTotalMinionsKilled  \
# 8525                17259                     185
#
#       blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  \
# 8525                            53           677                -738
#
#       blueCSPerMin  blueGoldPerMin  redWardsPlaced  redWardsDestroyed  \
# 8525     20.548858     1561.157845              14                  1
#
#       redFirstBlood  redKills  redDeaths  redAssists  redDragons  redHeralds  \
# 8525              1         6          3           5           0           0
#
#       redEliteMonsters  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 8525                 0                   0         14732          6.4
#
#       redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 8525               16521                    191                           49
#
#       redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 8525         -677                738    21.215308    1636.355558         1

# %%
# Finding the matchId
df_eune.loc[df_eune["blueWardsPlaced"]==306]
# Out:
#                matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 13825  EUN1_3249937829              306                   2               1
#
#        blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 13825          2           6            1            0            0
#
#        blueEliteMonsters  blueTowersDestroyed  blueTotalGold  blueAvgLevel  \
# 13825                  0                    0          13234           6.4
#
#        blueTotalExperience  blueTotalMinionsKilled  \
# 13825                15712                     187
#
#        blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  \
# 13825                            42          1272                 923
#
#        blueCSPerMin  blueGoldPerMin  redWardsPlaced  redWardsDestroyed  \
# 13825     20.771585     1470.006165              10                 14
#
#        redFirstBlood  redKills  redDeaths  redAssists  redDragons  redHeralds  \
# 13825              0         6          2           3           0           0
#
#        redEliteMonsters  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 13825                 0                   0         14506          6.8
#
#        redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 13825               16635                    180                           41
#
#        redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 13825        -1272               -923    19.994039    1611.297372         1

# %% [markdown]
# We manualy searched through about 10 games that appeared in our dataset, which have more than 200 wards by either team. Riot marks most of the wards by one character (Warwick) as UNDEFINED.

# %%
# Finding matchId-s to check participating characters in the game
df_eune[(df_eune["blueWardsPlaced"] > 200) | (df_eune["redWardsPlaced"] > 200)]
# Out:
#                matchId  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 265    EUN1_3246750364                8                   1               1
# 342    EUN1_3226042360              207                  14               1
# 344    EUN1_3217937111              214                   1               0
# 600    EUN1_3250239128               33                   3               1
# 1063   EUN1_3245723176               11                   2               0
# ...                ...              ...                 ...             ...
# 15055  EUN1_3226910291               30                   0               1
# 15121  EUN1_3227333388               79                   3               0
# 15403  EUN1_3181921263               11                   2               1
# 15437  EUN1_3245114886              278                   1               0
# 15451  EUN1_3233836810               17                   3               0
#
#        blueKills  blueDeaths  blueAssists  blueDragons  blueHeralds  \
# 265            4           6            2            0            0
# 342            2           6            0            0            0
# 344            2           6            2            0            0
# 600            4           6            3            0            1
# 1063           5           7            6            0            0
# ...          ...         ...          ...          ...          ...
# 15055          8           6           18            0            0
# 15121          7           5            9            0            0
# 15403          5           2            2            1            0
# 15437          5          10            5            0            0
# 15451          4           6            2            0            0
#
#        blueEliteMonsters  blueTowersDestroyed  blueTotalGold  blueAvgLevel  \
# 265                    0                    0          13965           6.4
# 342                    0                    0          13474           6.4
# 344                    0                    0          13838           6.4
# 600                    1                    0          14305           6.4
# 1063                   0                    0          14831           6.4
# ...                  ...                  ...            ...           ...
# 15055                  0                    0          15513           6.2
# 15121                  0                    0          15947           6.4
# 15403                  1                    0          14705           6.4
# 15437                  0                    0          13620           6.2
# 15451                  0                    0          14784           6.8
#
#        blueTotalExperience  blueTotalMinionsKilled  \
# 265                  15582                     185
# 342                  15881                     190
# 344                  14936                     198
# 600                  15660                     158
# 1063                 14821                     205
# ...                    ...                     ...
# 15055                15094                     164
# 15121                16517                     186
# 15403                15995                     186
# 15437                14591                     136
# 15451                17162                     192
#
#        blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  \
# 265                              48          1268                1161
# 342                              48          1119                 696
# 344                              38          1011                 485
# 600                              52           927                 169
# 1063                             25           668                -465
# ...                             ...           ...                 ...
# 15055                            48          -671                -804
# 15121                            55         -1866               -2548
# 15403                            55         -1065                 509
# 15437                            60          3784                1239
# 15451                            64            50                -311
#
#        blueCSPerMin  blueGoldPerMin  redWardsPlaced  redWardsDestroyed  \
# 265       20.551750     1551.379374             209                  1
# 342       21.103764     1496.590076              32                  2
# 344       21.994705     1537.185492              10                  1
# 600       17.551395     1589.067777             244                  2
# 1063      22.771537     1647.437369             252                  1
# ...             ...             ...             ...                ...
# 15055     18.217061     1723.178433             203                 10
# 15121     20.660086     1771.324689             275                  3
# 15403     20.658939     1633.277922             288                  3
# 15437     15.106160     1512.837459              12                  2
# 15451     21.324882     1642.015942             219                  5
#
#        redFirstBlood  redKills  redDeaths  redAssists  redDragons  redHeralds  \
# 265                0         6          4           7           1           0
# 342                0         6          2           7           1           0
# 344                1         6          2          10           1           0
# 600                0         6          4           6           1           0
# 1063               1         7          5           7           0           0
# ...              ...       ...        ...         ...         ...         ...
# 15055              0         6          8           7           1           0
# 15121              1         5          7           8           1           0
# 15403              0         2          5           1           0           0
# 15437              1        10          5           7           0           0
# 15451              1         6          4           6           1           0
#
#        redEliteMonsters  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 265                   1                   0         15233          6.6
# 342                   1                   0         14593          6.6
# 344                   1                   0         14849          6.4
# 600                   1                   0         15232          6.4
# 1063                  0                   0         15499          6.4
# ...                 ...                 ...           ...          ...
# 15055                 1                   0         14842          5.8
# 15121                 1                   0         14081          5.8
# 15403                 0                   0         13640          6.6
# 15437                 0                   0         17404          6.6
# 15451                 1                   0         14834          6.8
#
#        redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 265                 16743                    185                           48
# 342                 16577                    169                           56
# 344                 15421                    179                           62
# 600                 15829                    177                           60
# 1063                14356                    165                           32
# ...                   ...                    ...                          ...
# 15055               14290                    150                           48
# 15121               13969                    157                           36
# 15403               16504                    204                           48
# 15437               15830                    197                           40
# 15451               16851                    199                           40
#
#        redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin  bluewins
# 265          -1268              -1161    20.551750    1692.242177         1
# 342          -1119               -696    18.771243    1620.880138         0
# 344          -1011               -485    19.884102    1649.491789         0
# 600           -927               -169    19.662006    1692.043367         0
# 1063          -668                465    18.328310    1721.639254         0
# ...            ...                ...          ...            ...       ...
# 15055          671                804    16.661946    1648.643995         1
# 15121         1866               2548    17.438890    1564.057374         1
# 15403         1065               -509    22.658191    1514.988838         1
# 15437        -3784              -1239    21.881717    1933.144136         0
# 15451          -50                311    22.102352    1647.569297         0
#
# [76 rows x 40 columns]

# %% [markdown]
# Since there are 162 champions in League of Legends and many of them have abilities that give vision, we decided that we will remove games from our dataset that have more than 50 wards placed by either team. We are aware that this could influence the machine learning algorithm, but we think that these characters skew the warding data too much so we have decided to leave out games with an unrealistic amount of wards.

# %% [markdown]
# In addition, we noticed that the Kaggle dataset (https://www.kaggle.com/datasets/bobbyscience/league-of-legends-diamond-ranked-games-10-min) that we had as an inspiration has included those values that we will remove.

# %%
# Number of games that have more than 50 wards by either team EUW
len(df_euw[(df_euw["blueWardsPlaced"] > 50) | (df_euw["redWardsPlaced"] > 50)])
# Out:
# 1801

# %%
# Number of games that have more than 50 wards by either team EUNE
len(df_eune[(df_eune["blueWardsPlaced"] > 50) | (df_eune["redWardsPlaced"] > 50)])
# Out:
# 1774

# %%
# Removing rows with too many wards EUW
df_euw = df_euw[(df_euw["blueWardsPlaced"] <= 50) & (df_euw["redWardsPlaced"] <= 50)]

# %%
# # Removing rows with too many wards EUNE
df_eune = df_eune[(df_eune["blueWardsPlaced"] <= 50) & (df_eune["redWardsPlaced"] <= 50)]

# %%
print(len(df_eune))
print(len(df_euw))
# Out:
# 14477
# 14182

# %% [markdown]
# The data can still include some duplicate values (games) because players from the same server and similar rank play together in ranked games.

# %% [markdown]
# ### Removing duplicate values

# %% [markdown]
# We are counting unique matchId-s because each game has its own id.

# %%
print("EUNE game count: " + str(len(df_eune)))
print("EUNE unique game count: " +str(len(df_eune["matchId"].drop_duplicates())))
# Out:
# EUNE game count: 14477
# EUNE unique game count: 13165

# %%
print("EUW game count: " + str(len(df_euw)))
print("EUW unique game count: " +str(len(df_euw["matchId"].drop_duplicates())))
# Out:
# EUW game count: 14182
# EUW unique game count: 13508

# %%
df_eune = df_eune.drop_duplicates()
df_euw = df_euw.drop_duplicates()

# %% [markdown]
# ### Balancing the dataset

# %% [markdown]
# It is not possible to have a tie. This means that either blue or red team has to win.

# %% [markdown]
# Counting how many blue wins (same as red loses) and loses (same as red wins) each server has, to determine how to balance data.

# %%
eune_bluewin_amount = len(df_eune[df_eune["bluewins"]==1])
eune_bluelose_amount = len(df_eune[df_eune["bluewins"]==0])
print("EUNE blue wins: ", eune_bluewin_amount)
print("EUNE blue loses (red wins): ", eune_bluelose_amount)
# Out:
# EUNE blue wins:  6493
# EUNE blue loses (red wins):  6672

# %%
euw_bluewin_amount = len(df_euw[df_euw["bluewins"]==1])
euw_bluelose_amount = len(df_euw[df_euw["bluewins"]==0])
print("EUW blue wins: ", euw_bluewin_amount)
print("EUW blue loses (red wins): ", euw_bluelose_amount)
# Out:
# EUW blue wins:  6595
# EUW blue loses (red wins):  6913

# %% [markdown]
# We are using random undersampling because we only want to have unique games.

# %% [markdown]
# First we find minimum of winning and losing games and then the minimum out of those. This is because we want both servers to have the same amount of positive and negative outcomes. There is no need to take the wins or losses into account when comparing the servers, so this balance will not influence the comparisons.

# %%
bluewins_amount = min(eune_bluewin_amount,euw_bluewin_amount)
blueloses_amount = min(eune_bluelose_amount, euw_bluelose_amount)
game_amount = min(bluewins_amount,blueloses_amount)

# %%
# replace=False is default, this means that there will be no duplicate values
eune_bluewins = df_eune[df_eune["bluewins"]==1].sample(n=game_amount, random_state=0)
eune_blueloses = df_eune[df_eune["bluewins"]==0].sample(n=game_amount, random_state=0)
euw_bluewins = df_euw[df_euw["bluewins"]==1].sample(n=game_amount, random_state=0)
euw_blueloses = df_euw[df_euw["bluewins"]==0].sample(n=game_amount, random_state=0)

# %%
df_eune_balanced = pd.concat([eune_bluewins, eune_blueloses])

# %%
df_euw_balanced = pd.concat([euw_bluewins, euw_blueloses])

# %% [markdown]
# While searching for correlations (later in the notebook), we found that we have made a mistake in gathering data. The mistake was that blueGoldDiff and redGoldDiff, redExperienceDiff and blueExperienceDiff should be swapped. We found the mistake because it did not make sense that blue team having more gold negatively influences the bluewins column.
# Since both of these pairs are additive inverse of each other, we can just multiply the data by -1.

# %%
df_eune_balanced["blueGoldDiff"] = df_eune_balanced["blueGoldDiff"].apply(lambda x: x*-1)
df_eune_balanced["redGoldDiff"] = df_eune_balanced["redGoldDiff"].apply(lambda x: x*-1)
df_eune_balanced["blueExperienceDiff"] = df_eune_balanced["blueExperienceDiff"].apply(lambda x: x*-1)
df_eune_balanced["redExperienceDiff"] = df_eune_balanced["redExperienceDiff"].apply(lambda x: x*-1)

# %%
df_euw_balanced["blueGoldDiff"] = df_euw_balanced["blueGoldDiff"].apply(lambda x: x*-1)
df_euw_balanced["redGoldDiff"] = df_euw_balanced["redGoldDiff"].apply(lambda x: x*-1)
df_euw_balanced["blueExperienceDiff"] = df_euw_balanced["blueExperienceDiff"].apply(lambda x: x*-1)
df_euw_balanced["redExperienceDiff"] = df_euw_balanced["redExperienceDiff"].apply(lambda x: x*-1)

# %% [markdown]
# # Data after cleaning

# %% [markdown]
# We have removed duplicate values, removed some extreme values and balanced the data for both servers.

# %%
df_eune_balanced.describe()
# Out:
#        blueWardsPlaced  blueWardsDestroyed  blueFirstBl
# 50%                       48.000000      7.000000           -1.500000
# 75%                       56.000000   1425.000000          964.000000
# max                       88.000000  10075.000000         7154.000000
#
#        blueCSPerMin  blueGoldPerMin  redWardsPlaced  redWardsDestroyed  \
# count  12986.000000    12986.000000    12986.000000       12986.000000
# mean      20.853922     1683.635954       15.563992           1.960804
# std        2.183499      159.137590        7.690406           1.814863
# min        5.554146      973.522798        2.000000           0.000000
# 25%       19.439090     1572.423445       12.000000           1.000000
# 50%       20.992167     1673.610578       13.000000           2.000000
# 75%       22.327173     1782.132582       16.000000           3.000000
# max       28.437809     2480.949101       50.000000          25.000000
#
#        redFirstBlood      redKills     redDeaths    redAssists    redDragons  \
# count   12986.000000  12986.000000  12986.000000  12986.000000  12986.000000
# mean        0.501155      5.651240      5.688973      5.943170      0.244032
# std         0.500018      2.815949      2.846622      3.868896      0.429528
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      4.000000      4.000000      3.000000      0.000000
# 50%         1.000000      5.000000      5.000000      5.000000      0.000000
# 75%         1.000000      7.000000      7.000000      8.000000      0.000000
# max         1.000000     21.000000     20.000000     34.000000      1.000000
#
#          redHeralds  redEliteMonsters  redTowersDestroyed  redTotalGold  \
# count  12986.000000      12986.000000        12986.000000  12986.000000
# mean       0.080779          0.324811            0.005236  15149.218543
# std        0.272506          0.505186            0.083088   1427.955115
# min        0.000000          0.000000            0.000000  10722.000000
# 25%        0.000000          0.000000            0.000000  14133.000000
# 50%        0.000000          0.000000            0.000000  15043.000000
# 75%        0.000000          1.000000            0.000000  16041.750000
# max        1.000000          2.000000            5.000000  23235.000000
#
#        redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# count  12986.00000        12986.000000           12986.000000
# mean       6.42361        15821.773063             188.164485
# std        0.27761          986.153431              19.574296
# min        4.40000         9618.000000              96.000000
# 25%        6.20000        15205.000000             175.000000
# 50%        6.40000        15846.000000             189.000000
# 75%        6.60000        16474.000000             201.000000
# max        7.40000        19906.000000             266.000000
#
#        redTotalJungleMinionsKilled   redGoldDiff  redExperienceDiff  \
# count                 12986.000000  12986.000000       12986.000000
# mean                     49.992684     -8.135531          10.937163
# std                       9.107624   2181.976944        1525.285752
# min                       0.000000 -10075.000000       -7154.000000
# 25%                      44.000000  -1425.000000        -964.000000
# 50%                      49.000000     -7.000000           1.500000
# 75%                      56.000000   1400.000000         987.000000
# max                      84.000000  12288.000000        9405.000000
#
#         redCSPerMin  redGoldPerMin      bluewins
# count  12986.000000   12986.000000  12986.000000
# mean      20.900703    1682.726447      0.500000
# std        2.173785     158.575402      0.500019
# min       10.662500    1190.870217      0.000000
# 25%       19.440214    1569.841872      0.000000
# 50%       20.992264    1671.070001      0.500000
# 75%       22.329033    1781.878789      1.000000
# max       28.769839    2580.772955      1.000000

# %%
df_euw_balanced.shape
# Out:
# (12986, 40)

# %%
# Write data to csv files 
filepath1 = Path('clean_eune.csv')
filepath2 = Path('clean_euw.csv')
df_eune_balanced.to_csv(filepath1)
df_euw_balanced.to_csv(filepath2)

# %% [markdown]
# # Correlations between game data and match result

# %% [markdown]
# It is likely that different servers have different playstyles. This means that we cannot combine those servers while searching for correlations. Both servers will be investigated separately.

# %% [markdown]
# ### EUNE correlations

# %%
eune_corr_matrix = df_eune_balanced.corr()
# There are too many attributes, so the font needs to be quite small
sns.set(font_scale=0.6)
sns.heatmap(eune_corr_matrix,cmap="YlGnBu")
plt.title("EUNE correlations", fontsize=15)
# Out:
# Text(0.5, 1.0, 'EUNE correlations')

# %% [markdown]
# Since our goal is to find correlations between game data and match result (bluewins), we only look at bluewins column from the matrix.

# %%
# Sorting bluewins column correlations by descending
abs(eune_corr_matrix["bluewins"]).sort_values(ascending=False)
# Out:
# bluewins                        1.000000
# blueGoldDiff                    0.463782
# redGoldDiff                     0.463782
# redExperienceDiff               0.413971
# blueExperienceDiff              0.413971
# blueGoldPerMin                  0.358372
# blueTotalGold                   0.358169
# redGoldPerMin                   0.350298
# redTotalGold                    0.349742
# blueTotalExperience             0.318804
# redTotalExperience              0.315929
# redDeaths                       0.301064
# blueKills                       0.301064
# redKills                        0.291282
# blueDeaths                      0.291282
# redAvgLevel                     0.282660
# blueAvgLevel                    0.274980
# blueAssists                     0.234136
# redAssists                      0.230824
# redCSPerMin                     0.194815
# redTotalMinionsKilled           0.194633
# blueTotalMinionsKilled          0.187326
# blueCSPerMin                    0.187322
# blueFirstBlood                  0.184695
# redFirstBlood                   0.184544
# redEliteMonsters                0.177037
# redDragons                      0.175606
# blueEliteMonsters               0.173990
# blueDragons                     0.171660
# redTotalJungleMinionsKilled     0.111329
# blueTotalJungleMinionsKilled    0.110961
# redHeralds                      0.047905
# blueHeralds                     0.047255
# redWardsDestroyed               0.045373
# blueWardsDestroyed              0.043211
# blueTowersDestroyed             0.034526
# redTowersDestroyed              0.027125
# redWardsPlaced                  0.024008
# blueWardsPlaced                 0.016884
# Name: bluewins, dtype: float64

# %% [markdown]
# As expected, blueGoldDiff and redGoldDiff, redExperienceDiff and blueExperienceDiff, redDeaths and blueKills, redKills and blueDeaths all have the same correlation in pairs, because they are either additive inverse of the other or the same.

# %%
norm = TwoSlopeNorm(vmin=-1, vcenter=0, vmax=1)
colors = [plt.cm.YlGnBu(norm(c)) for c in eune_corr_matrix["bluewins"].values]
eune_corr_matrix["bluewins"].plot.barh(color=colors)
plt.title("EUNE correlations between game data and match result", fontsize=15)
# Out:
# Text(0.5, 1.0, 'EUNE correlations between game data and match result')

# %% [markdown]
# ### EUW correlations

# %% [markdown]
# We do the exact sames steps for EUW as we have done for EUNE

# %%
euw_corr_matrix = df_euw_balanced.corr()
sns.heatmap(euw_corr_matrix, cmap="YlGnBu")
plt.title("EUW correlations", fontsize=15)
# Out:
# Text(0.5, 1.0, 'EUW correlations')

# %%
# Sorting bluewins column correlations by descending
abs(euw_corr_matrix["bluewins"]).sort_values(ascending=False)
# Out:
# bluewins                        1.000000
# redGoldDiff                     0.477467
# blueGoldDiff                    0.477467
# redExperienceDiff               0.423001
# blueExperienceDiff              0.423001
# blueTotalGold                   0.370142
# blueGoldPerMin                  0.370117
# redGoldPerMin                   0.358300
# redTotalGold                    0.358272
# blueTotalExperience             0.333556
# redTotalExperience              0.315416
# blueKills                       0.308266
# redDeaths                       0.308266
# redKills                        0.297677
# blueDeaths                      0.297677
# blueAvgLevel                    0.289797
# redAvgLevel                     0.273460
# blueAssists                     0.260644
# redAssists                      0.251834
# blueTotalMinionsKilled          0.192343
# blueCSPerMin                    0.192338
# blueFirstBlood                  0.181889
# redFirstBlood                   0.181735
# blueDragons                     0.179581
# redTotalMinionsKilled           0.179171
# redCSPerMin                     0.179156
# blueEliteMonsters               0.177131
# redDragons                      0.169785
# redEliteMonsters                0.164022
# blueTotalJungleMinionsKilled    0.100804
# redTotalJungleMinionsKilled     0.099309
# blueHeralds                     0.050797
# blueWardsDestroyed              0.042455
# redWardsDestroyed               0.041796
# redTowersDestroyed              0.038927
# redHeralds                      0.036455
# blueTowersDestroyed             0.029015
# blueWardsPlaced                 0.026793
# redWardsPlaced                  0.025435
# Name: bluewins, dtype: float64

# %%
colors = [plt.cm.YlGnBu(norm(c)) for c in euw_corr_matrix["bluewins"].values]
euw_corr_matrix["bluewins"].plot.barh(color=colors)
plt.title("EUW correlations between game data and match result", fontsize=15)
# Out:
# Text(0.5, 1.0, 'EUW correlations between game data and match result')

# %% [markdown]
# ### Something about correlations !!!

# %% [markdown]
# We notice, that for both servers in our dataset, gold and experience are the two attributes influencing the match result the most.

# %% [markdown]
# Visualy there is almost no difference between both server's correlation plots.

# %% [markdown]
# # Dividing data for models

# %% [markdown]
# First of all, let's define the features we will use for training our models, since using all of them is unnecessary due to some defining the others. (for example, blue kills defining red deaths, blueFirstBlood defining redFirstBlood etc.). Killing minions only provides gold and experience, so those columns are redundant aswell. \
# We will drop the features we are not using.

# %%
drop = ['matchId', 'redFirstBlood', 'redKills', 'redEliteMonsters', 'redDragons','redTotalMinionsKilled',
       'redTotalJungleMinionsKilled', 'redGoldDiff', 'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin', 'redHeralds',
       'blueGoldDiff', 'blueExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'blueTotalMinionsKilled']
df_euw_balanced.drop(drop, axis=1)
df_eune_balanced.drop(drop, axis=1)
# Out:
#        blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 13589               17                   1               1          7
# 3226                11                   3               1          4
# 3068                11                   0               0          4
# 8505                18                   2               0          5
# 13578               20                   3               0          5
# ...                ...                 ...             ...        ...
# 2597                25                   0               1          6
# 5176                14                   2               0          5
# 11954               10                   2               0          3
# 7620                12                   0               1          7
# 3486                13                   2               1          3
#
#        blueDeaths  blueAssists  blueDragons  blueHeralds  blueEliteMonsters  \
# 13589           3           13            1            0                  1
# 3226            3            4            1            0                  1
# 3068            6            5            0            0                  0
# 8505            3            7            0            0                  0
# 13578           6            7            1            0                  1
# ...           ...          ...          ...          ...                ...
# 2597            3            4            0            0                  0
# 5176            7            4            0            0                  0
# 11954           8            5            0            0                  0
# 7620            6            3            0            0                  0
# 3486            7            4            0            0                  0
#
#        blueTowersDestroyed  blueTotalGold  blueAvgLevel  blueTotalExperience  \
# 13589                    0          16263           6.6                16034
# 3226                     0          14728           6.4                16195
# 3068                     0          15279           6.6                16445
# 8505                     0          15062           6.2                15244
# 13578                    0          15471           6.8                17006
# ...                    ...            ...           ...                  ...
# 2597                     0          14552           6.6                16024
# 5176                     0          14368           6.0                14829
# 11954                    0          12561           6.0                13893
# 7620                     0          15299           6.6                16832
# 3486                     0          13798           6.2                14842
#
#        blueTotalJungleMinionsKilled  redWardsPlaced  redWardsDestroyed  \
# 13589                            52              12                  1
# 3226                             59              14                  4
# 3068                             56              10                  2
# 8505                             56              10                  3
# 13578                            55              17                  0
# ...                             ...             ...                ...
# 2597                             56              12                  0
# 5176                             36              12                  3
# 11954                            36               9                  0
# 7620                             40              10                  0
# 3486                             40              14                  2
#
#        redDeaths  redAssists  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 13589          7           5                   0         14391          6.6
# 3226           4           3                   0         13338          6.2
# 3068           4          12                   0         16022          6.6
# 8505           5           7                   0         13459          6.2
# 13578          5           5                   0         15682          6.8
# ...          ...         ...                 ...           ...          ...
# 2597           6           3                   0         14247          6.6
# 5176           5           9                   0         15621          6.4
# 11954          3           1                   0         15281          7.0
# 7620           7           6                   0         13807          6.6
# 3486           3           6                   0         16696          6.6
#
#        redTotalExperience  bluewins
# 13589               16258         1
# 3226                14737         1
# 3068                16048         1
# 8505                14904         1
# 13578               17022         1
# ...                   ...       ...
# 2597                16214         0
# 5176                15476         0
# 11954               17017         0
# 7620                16502         0
# 3486                16819         0
#
# [12986 rows x 23 columns]

# %% [markdown]
# Split up the data into training sets and test sets.

# %%
features_euw = df_euw_balanced.drop("bluewins",axis=1)
features_eune = df_eune_balanced.drop("bluewins",axis=1)

target_euw = df_euw_balanced["bluewins"]
target_eune = df_eune_balanced["bluewins"]

X_train_euw, X_test_euw, y_train_euw, y_test_euw = train_test_split(features_euw,target_euw,test_size=0.2,random_state=5)
X_train_eune, X_test_eune, y_train_eune, y_test_eune = train_test_split(features_eune,target_eune,test_size=0.2,random_state=5)

# %% [markdown]
# # Creating models

# %% [markdown]
# xxx

# %% [markdown]
# # Optimizing the model

# %% [markdown]
# xxx

# %% [markdown]
# # Validating the model

# %% [markdown]
# xxx

# %% [markdown]
# # Summary of building a model

# %% [markdown]
# xxx

# %% [markdown]
# # Comparing EUNE and EUW servers

# %% [markdown]
# xxx

# %%
df_eune_balanced.describe()

# %%
df_euw_balanced.describe()

# %%
fig, axes = plt.subplots(1,2,figsize=(6,6), sharey=True)

sns.violinplot(ax=axes[0], y="blueTotalGold", data=df_eune_balanced, color='b')
sns.violinplot(ax=axes[1], y="redTotalGold", data=df_eune_balanced, color='r')

axes[0].set_ylabel("Total Gold", fontsize=12)
axes[1].set_ylabel("")

axes[0].set_xlabel("Blue team", fontsize=12)
axes[1].set_xlabel("Red team", fontsize=12)

fig.suptitle("EUNE total gold per team", fontsize=15)

# %%
fig, axes = plt.subplots(1,2,figsize=(6,6), sharey=True)

sns.violinplot(ax=axes[0], y="blueTotalGold", data=df_euw_balanced, color='b')
sns.violinplot(ax=axes[1], y="redTotalGold", data=df_euw_balanced, color='r')

axes[0].set_ylabel("Total Gold", fontsize=12)
axes[1].set_ylabel("")

axes[0].set_xlabel("Blue team", fontsize=12)
axes[1].set_xlabel("Red team", fontsize=12)

fig.suptitle("EUW total gold per team", fontsize=15)

# %% [markdown]
# # Summary of comparing servers

# %% [markdown]
# xxx
